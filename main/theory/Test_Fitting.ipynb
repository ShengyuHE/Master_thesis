# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
def dataload(data):
    Pk0 = [[],[]]
    Pk2 = [[],[]]
    k = data[0,:,1]
    l0 = data[:,:,3]
    l2 = data[:,:,4]
    Pk0[0] = np.mean(l0,axis=0)
    Pk0[1] = np.std(l0,axis=0)
    Pk2[0] = np.mean(l2,axis=0)
    Pk2[1] = np.std(l2,axis=0)
    pk_cov = np.append(l0,l2,axis=1)
    cov = np.cov(np.array(pk_cov).T)
    icov = np.linalg.inv(cov)
    return (k,Pk0,Pk2,icov)

def Pkload():
    # load the QUIJOTE observation
    tool = 'Pypower' # Powspec, Pypower, NCV
    Ddir = f'/Users/alain/Desktop/projectNU/main/data/Pypower/fiducial/RSD_z1.0/pk'
    data = []
    nb = np.arange(100,200,1)
    for h in nb:
        realisation=np.loadtxt(Ddir+f'/fiducial_{h}_z1.0.pk')
        data.append(realisation)
    (kev, pk0, pk2, icov) = dataload(np.array(data))
    pkl = [kev, pk0, pk2, icov]
    return pkl

# %%
import RSDmodel as RSD
from nautilus import Prior, Sampler

(k_data, pk0, pk2, icov) = Pkload()
pk_data = np.append(pk0[0], pk2[0])
k_ev = k_data

def Nprior():
    prior = Prior()
    param_names = ['h', 'omega_cdm', 'logA', 'Mnu', 'b1', 'b2', 'alpha0', 'alpha2', 'sn0', 'sn2']
    prior.add_parameter('h', dist=(0.1, 0.9))
    prior.add_parameter('omega_cdm', dist=(0.05, 0.4))
    prior.add_parameter('logA', dist=(2, 4))
    prior.add_parameter('Mnu', dist=(0.0, 2.0))
    prior.add_parameter('b1', dist=(-10, 10))
    prior.add_parameter('b2', dist=(-10, 10))
    prior.add_parameter('alpha0', dist=(-300, 300))
    prior.add_parameter('alpha2', dist=(-300, 300))
    prior.add_parameter('sn0', dist=(-5, 5))
    prior.add_parameter('sn2', dist=(-50, 50))
    return prior

def likelihood(param_dict):
    p = np.array([param_dict['h'], param_dict['omega_cdm'],param_dict['logA'], param_dict['Mnu']
                  ,param_dict['b1'],param_dict['b2'],param_dict['alpha0'],param_dict['alpha2'],param_dict['sn0'],param_dict['sn2']])
    #define log likelihood
    (k_model,pkl0_model,pkl2_model) = RSD.FOLPSmultiples(p,k_ev)
    pk_model = np.append(pkl0_model,pkl2_model)
    diff = pk_data-pk_model
    chisquare = np.dot(diff,np.dot(icov,diff)) 
    logL = -0.5*chisquare
    #returning the natural logarithm of the likelihood. log(L) = -0.5*chi^2
    return logL
# Out:
# N = 128 sampling points
# M matrices have been computed

# %%
sampler = Sampler(Nprior(), likelihood, n_live=1000,
    filepath='/Nautilus_result/', resume=True)
sampler.run(verbose=True)
# Out:
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# /Users/alain/opt/anaconda3/lib/python3.9/site-packages/scipy/special/_logsumexp.py:110: RuntimeWarning: overflow encountered in exp
#   tmp = np.exp(a - a_max)
# /Users/alain/opt/anaconda3/lib/python3.9/site-packages/nautilus/sampler.py:644: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(self.shell_log_l + self.shell_log_v))[select]
# /Users/alain/opt/anaconda3/lib/python3.9/site-packages/nautilus/sampler.py:646: RuntimeWarning: invalid value encountered in scalar divide
#   return np.sum(sum_w)**2 / np.sum(sum_w_sq)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/n0/gs1g7p590qg7trf8pp8w29ch0000gn/T/ipykernel_4745/1653691644.py in <module>
#       1 sampler = Sampler(Nprior(), likelihood, n_live=1000,
#       2     filepath='./chains/checkpoint.hdf5', resume=True)
# ----> 3 sampler.run(verbose=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/nautilus/sampler.py in run(self, f_live, n_shell, n_eff, n_like_max, discard_exploration, timeout, verbose)
#     440                         self.write(self.filepath, overwrite=True)
#     441
# --> 442                 self.n_update_iter += self.add_samples(-1, verbose=verbose)
#     443                 self.n_like_iter += self.n_batch
#     444                 if self.filepath is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/nautilus/sampler.py in add_samples(self, shell, verbose)
#    1083         """
#    1084         if verbose:
# -> 1085             self.print_status('Sampling', end='\r')
#    1086
#    1087         if shell == -1 and len(self.shell_t) > 0:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/nautilus/sampler.py in print_status(self, status, header, end)
#     938             else:
#     939                 data.extend([0, 0])
# --> 940             data.extend([self.n_like, self.f_live, self.n_eff, self.log_z])
#     941
#     942             fmt = ['{}', '{:d}', '{:d}', '{:d}', '{:d}', '{:.4f}', '{:.0f}',
#
# ~/opt/anaconda3/lib/python3.9/site-packages/nautilus/sampler.py in log_z(self)
#     673             return None
#     674         select = ~np.isnan(self.shell_log_l)
# --> 675         return logsumexp(self.shell_log_l[select] + self.shell_log_v[select])
#     676
#     677     def evidence(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/special/_logsumexp.py in logsumexp(a, axis, b, keepdims, return_sign)
#      97             a[b == 0] = -np.inf
#      98
# ---> 99     a_max = np.amax(a, axis=axis, keepdims=True)
#     100
#     101     if a_max.ndim > 0:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/overrides.py in amax(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2818     5
#    2819     """
# -> 2820     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2821                           keepdims=keepdims, initial=initial, where=where)
#    2822
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
import RSDmodel as RSD
import emcee

(k_data, pk0, pk2, icov) = Pkload()
pk_data = np.append(pk0[0], pk2[0])

# h, Omega_cdm, Mnu, ln(10^{10}A_s), b1, b2, alpha0, alpha2, alphashot0, alphashot2
# p_kaiser = [h, omega_cdm, logA, b1, sv]
p0 = [0.6711, 0.1209, 3.0631, 2.0, 400]

def log_likelihood(p,k_data,pk_data,icov):
    (h, omega_cdm, logA, b1, sv)= p
    #define prior
    if h<0.5 or h>0.7:
        return -np.inf
    elif omega_cdm<0.05 or omega_cdm>0.2:
        return -np.inf
    elif logA<2 or logA>4:
        return -np.inf
    # Biased tracers -- b1:[1,2], b2:[-5,5]
    elif b1<-5 or b1>5:
        return -np.inf
    elif sv<100 or sv>800:
        return -np.inf
    #define log likelihood
    (kh, Pkl0, Pkl2) = RSD.Kaisermultiples(p, k_data)
    pk_model = np.append(Pkl0, Pkl2)
    diff = pk_data-pk_model
    logL = -0.5*np.dot(diff,np.dot(icov,diff))
    return logL

nwalkers = 50 # need to be at least twice the number of dimension
save_output = True
startpos = p0
pos = startpos + 1e-4 * np.random.randn(nwalkers, len(startpos)) # initialise the walkers
nwalkers, ndim = pos.shape

sampler = emcee.EnsembleSampler(nwalkers, ndim, log_likelihood, args=(k_data,pk_data,icov))
sampler.run_mcmc(pos, 500, progress=True, store=True)
# Out:
# emcee: Exception while calling your likelihood function:
#   params: [6.71204200e-01 1.20897760e-01 3.06318179e+00 2.00005474e+00
#  4.00000017e+02]
#   args: (array([0.008, 0.014, 0.02 , 0.026, 0.032, 0.038, 0.044, 0.05 , 0.056,
#        0.062, 0.068, 0.074, 0.08 , 0.086, 0.092, 0.098, 0.104, 0.11 ,
#        0.116, 0.122, 0.128, 0.134, 0.14 , 0.146, 0.152, 0.158, 0.164,
#        0.17 , 0.176, 0.182, 0.188, 0.194, 0.2  ]), array([60321.61099538, 71764.38276658, 72110.47955228, 63848.04266528,
#        53706.46789523, 46698.48719264, 40330.8360877 , 36256.73298296,
#        33733.56682468, 31485.37188526, 29340.73033541, 27228.08042694,
#        24331.70690965, 21994.20773041, 19715.98978839, 17792.13837996,
#        16295.34774592, 15083.69508102, 14339.17292056, 13758.38731561,
#        13005.21253903, 12388.16828211, 11633.19405586, 10863.48199591,
#        10209.07576773,  9510.56852717,  8996.87100619,  8507.09838736,
#         8209.64693798,  7849.29304402,  7563.02492623,  7237.41177065,
#         6970.02583025, 23904.37105786, 29952.40436187, 28253.71588658,
#        26417.58822289, 20972.72628524, 17955.1111395 , 15624.15586768,
#        14260.22522205, 13698.40035275, 13010.65826221, 12189.71558554,
#        10904.8918951 ,  9748.01659101,  8884.85038107,  8099.0424439 ,
#         7303.00418053,  6947.11129736,  6654.99571543,  6103.34385801,
#         5899.866358  ,  5614.44882081,  5283.5988912 ,  4934.51049688,
#         4592.72332917,  4599.66858239,  4362.7437947 ,  4095.36812666,
#         3990.61227211,  3636.61528907,  3566.86733847,  3514.99788537,
#         3232.88755932,  3164.26804842]), array([[ 6.43695840e-09,  3.04646237e-09,  1.76264685e-09, ...,
#          3.75758793e-08, -7.52547714e-08,  4.85165534e-08],
#        [ 3.04646237e-09,  1.19803691e-08,  3.00604589e-09, ...,
#          1.19068086e-07, -2.13594561e-08,  1.03000979e-07],
#        [ 1.76264685e-09,  3.00604589e-09,  4.23775828e-08, ...,
#          9.33192322e-08, -1.17209033e-07, -7.23072581e-08],
#        ...,
#        [ 3.75758793e-08,  1.19068086e-07,  9.33192322e-08, ...,
#          9.13872271e-06, -2.00667781e-06,  1.17403389e-06],
#        [-7.52547714e-08, -2.13594561e-08, -1.17209033e-07, ...,
#         -2.00667781e-06,  1.67890939e-05,  3.15941506e-06],
#        [ 4.85165534e-08,  1.03000979e-07, -7.23072581e-08, ...,
#          1.17403389e-06,  3.15941506e-06,  1.37654665e-05]]))
#   kwargs: {}
#   exception:
# Traceback (most recent call last):
#   File "/Users/alain/opt/anaconda3/lib/python3.9/site-packages/emcee/ensemble.py", line 624, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "/var/folders/n0/gs1g7p590qg7trf8pp8w29ch0000gn/T/ipykernel_3705/2562729372.py", line 26, in log_likelihood
#     (kh, Pkl0, Pkl2) = RSD.Kaisermultiples(p, k_data)
#   File "/Users/alain/Desktop/projectNU/main/theory/RSDmodel.py", line 64, in Kaisermultiples
#     nonlinear = FOLPS.NonLinear(inputpkT, CosmoParams, EdSkernels = True)
#   File "/Users/alain/Desktop/projectNU/main/theory/./FOLPS-nu/FOLPSnu.py", line 828, in NonLinear
#     inputfkT = fOverf0EH(z_pk, inputpkT[0], OmM0, h, fnu)
#   File "/Users/alain/Desktop/projectNU/main/theory/./FOLPS-nu/FOLPSnu.py", line 513, in fOverf0EH
#     Dplusp_ = interp(etaofz(zev), eta, Dplusp)
#   File "/Users/alain/Desktop/projectNU/main/theory/./FOLPS-nu/FOLPSnu.py", line 36, in interp
#     inter = CubicSpline(x, y)
#   File "/Users/alain/opt/anaconda3/lib/python3.9/site-packages/scipy/interpolate/_cubic.py", line 781, in __init__
#     s = solve_banded((1, 1), A, b, overwrite_ab=True,
#   File "/Users/alain/opt/anaconda3/lib/python3.9/site-packages/scipy/linalg/_basic.py", line 452, in solve_banded
#     du2, d, du, x, info = gtsv(dl, d, du, b1, overwrite_ab, overwrite_ab,
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/n0/gs1g7p590qg7trf8pp8w29ch0000gn/T/ipykernel_3705/2562729372.py in <module>
#      37
#      38 sampler = emcee.EnsembleSampler(nwalkers, ndim, log_likelihood, args=(k_data,pk_data,icov))
# ---> 39 sampler.run_mcmc(pos, 500, progress=True, store=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/emcee/ensemble.py in run_mcmc(self, initial_state, nsteps, **kwargs)
#     441
#     442         results = None
# --> 443         for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     444             pass
#     445
#
# ~/opt/anaconda3/lib/python3.9/site-packages/emcee/ensemble.py in sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress, progress_kwargs)
#     342             state.blobs = blobs0
#     343         if state.log_prob is None:
# --> 344             state.log_prob, state.blobs = self.compute_log_prob(state.coords)
#     345         if np.shape(state.log_prob) != (self.nwalkers,):
#     346             raise ValueError("incompatible input dimensions")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/emcee/ensemble.py in compute_log_prob(self, coords)
#     487             else:
#     488                 map_func = map
# --> 489             results = list(map_func(self.log_prob_fn, p))
#     490
#     491         try:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/emcee/ensemble.py in __call__(self, x)
#     622     def __call__(self, x):
#     623         try:
# --> 624             return self.f(x, *self.args, **self.kwargs)
#     625         except:  # pragma: no cover
#     626             import traceback
#
# /var/folders/n0/gs1g7p590qg7trf8pp8w29ch0000gn/T/ipykernel_3705/2562729372.py in log_likelihood(p, k_data, pk_data, icov)
#      24         return -np.inf
#      25     #define log likelihood
# ---> 26     (kh, Pkl0, Pkl2) = RSD.Kaisermultiples(p, k_data)
#      27     pk_model = np.append(Pkl0, Pkl2)
#      28     diff = pk_data-pk_model
#
# ~/Desktop/projectNU/main/theory/RSDmodel.py in Kaisermultiples(p, kev)
#      62     omega_ncdm = Mnu/93.14
#      63     CosmoParams = [z_pk, omega_b, omega_cdm, omega_ncdm, h]
# ---> 64     nonlinear = FOLPS.NonLinear(inputpkT, CosmoParams, EdSkernels = True)
#      65     def PRSDs(k, mu, Table):
#      66         f0 =FOLPS.f0
#
# ~/Desktop/projectNU/main/theory/./FOLPS-nu/FOLPSnu.py in NonLinear(inputpkl, CosmoParams, kminout, kmaxout, nk, EdSkernels)
#     826     #Evaluation: f(k)/f0 and linear power spectrums
#     827     h, OmM0, fnu, Massnu = CosmoParam(h, omega_b, omega_cdm, omega_ncdm)
# --> 828     inputfkT = fOverf0EH(z_pk, inputpkT[0], OmM0, h, fnu)
#     829     f0 = inputfkT[2]
#     830
#
# ~/Desktop/projectNU/main/theory/./FOLPS-nu/FOLPSnu.py in fOverf0EH(zev, k, OmM0, h, fnu)
#     511     Dplus, Dplusp = odeint(Deqs, [Df0,Df_p0], eta).T
#     512
# --> 513     Dplusp_ = interp(etaofz(zev), eta, Dplusp)
#     514     Dplus_ = interp(etaofz(zev), eta, Dplus)
#     515     f0 = Dplusp_/Dplus_
#
# ~/Desktop/projectNU/main/theory/./FOLPS-nu/FOLPSnu.py in interp(k, x, y)
#      34         Cubic interpolation of ‘y’ evaluated at ‘k’.
#      35     '''
# ---> 36     inter = CubicSpline(x, y)
#      37     return inter(k)
#      38
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/interpolate/_cubic.py in __init__(self, x, y, axis, bc_type, extrapolate)
#     779                     b[-1] = 0.5 * bc_end[1] * dx[-1]**2 + 3 * (y[-1] - y[-2])
#     780
# --> 781                 s = solve_banded((1, 1), A, b, overwrite_ab=True,
#     782                                  overwrite_b=True, check_finite=False)
#     783
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/linalg/_basic.py in solve_banded(l_and_u, ab, b, overwrite_ab, overwrite_b, check_finite)
#     450         d = a1[1, :]
#     451         dl = a1[2, :-1]
# --> 452         du2, d, du, x, info = gtsv(dl, d, du, b1, overwrite_ab, overwrite_ab,
#     453                                    overwrite_ab, overwrite_b)
#     454     else:
#
# KeyboardInterrupt:

# %%
dir = './mcmc_result'
# reader = emcee.backends.HDFBackend(dir+"./chain.h5", read_only=True)
flatchain = sampler.get_chain(discard=100, thin=20,flat=True)

# %%
import corner
labels = ["h", "omega_cdm", "logA", "b1", "simga_v"]
fig = corner.corner(flatchain, labels=labels)

# %%
import RSDmodel as RSD
import emcee

(k_data, pk0, pk2, icov) = Pkload()
pk_data = np.append(pk0[0], pk2[0])

# h, Omega_cdm, Mnu, ln(10^{10}A_s), b1, b2, alpha0, alpha2, alphashot0, alphashot2
# p_TNS = [h, omega_cdm, logA, b1, b2, sv, sn0, sn2]
p0 = [0.6711, 0.1209, 3.0631, 2.4,  0.9,  400, 0.15, -8]

def log_likelihood(p,k_data,pk_data,icov):
    (h, omega_cdm, logA, b1, b2, sv, sn0, sn2)= p
    #define prior
    if h<0.5 or h>0.7:
        return -np.inf
    elif omega_cdm<0.05 or omega_cdm>0.2:
        return -np.inf
    elif logA<2 or logA>4:
        return -np.inf
    # Biased tracers -- b1:[1,2], b2:[-5,5]
    elif b1<-5 or b1>5:
        return -np.inf
    elif b1<-5 or b1>5:
        return -np.inf
    elif sv<100 or sv>800:
        return -np.inf
    elif sn
    #define log likelihood
    (kh, Pkl0, Pkl2) = RSD.TNSmultiples(p, k_data)
    pk_model = np.append(Pkl0, Pkl2)
    diff = pk_data-pk_model
    logL = -0.5*np.dot(diff,np.dot(icov,diff))
    return logL

nwalkers = 50 # need to be at least twice the number of dimension
save_output = True
startpos = p0
pos = startpos + 1e-4 * np.random.randn(nwalkers, len(startpos)) # initialise the walkers
nwalkers, ndim = pos.shape

sampler = emcee.EnsembleSampler(nwalkers, ndim, log_likelihood, args=(k_data,pk_data,icov))
sampler.run_mcmc(pos, 500, progress=True, store=True)
# Out:
#   File "/var/folders/n0/gs1g7p590qg7trf8pp8w29ch0000gn/T/ipykernel_24407/3989646887.py", line 27
#     elif sn
#            ^
# SyntaxError: invalid syntax
